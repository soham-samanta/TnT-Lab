# %%
#Soham Samanta | Roll : 20051107 | Lab-06

import pandas as pd
arr={
    'cars' : ["BMW","Audi","Merc"],
    'passings' : [3,7,2]
}
myVar = pd.DataFrame(arr)
print(myVar)
# Out:
#    cars  passings
# 0   BMW         3
# 1  Audi         7
# 2  Merc         2

# %%
import pandas as pd
df=pd.read_csv("datascience_salaries.csv")
print(df)
# Out:
#       Unnamed: 0       job_title    job_type experience_level       location  \
# 0              0  Data scientist   Full Time           Senior  New York City
# 1              2  Data scientist   Full Time           Senior         Boston
# 2              3  Data scientist   Full Time           Senior         London
# 3              4  Data scientist   Full Time           Senior         Boston
# 4              5  Data scientist   Full Time           Senior  New York City
# ...          ...             ...         ...              ...            ...
# 1166        2243          ML Ops   Full Time           Senior        Toronto
# 1167        2249          ML Ops   Full Time           Senior         Boston
# 1168        2250          ML Ops   Full Time           Senior          Delhi
# 1169        2255          ML Ops   Full Time           Senior  San Francisco
# 1170        2259          ML Ops  Internship           Senior  New York City
#
#      salary_currency  salary
# ...

# %%
df.shape
# Out:
# (1171, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'job_title', 'job_type', 'experience_level', 'location',
#        'salary_currency', 'salary'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'job_title',
#  'job_type',
#  'experience_level',
#  'location',
#  'salary_currency',
#  'salary']

# %%
df['location']
# Out:
# 0       New York City
# 1              Boston
# 2              London
# 3              Boston
# 4       New York City
#             ...
# 1166          Toronto
# 1167           Boston
# 1168            Delhi
# 1169    San Francisco
# 1170    New York City
# Name: location, Length: 1171, dtype: object

# %%
df['salary'].values
# Out:
# array([149000, 120000,  68000, ...,  76000,  68000, 135000])

# %%
df.head(3)
# Out:
#    Unnamed: 0       job_title   job_type experience_level       location  \
# 0           0  Data scientist  Full Time           Senior  New York City
# 1           2  Data scientist  Full Time           Senior         Boston
# 2           3  Data scientist  Full Time           Senior         London
#
#   salary_currency  salary
# 0             USD  149000
# 1             USD  120000
# 2             USD   68000

# %%
df.tail(12)
# Out:
#       Unnamed: 0 job_title    job_type experience_level  \
# 1159        2206    ML Ops   Full Time              Mid
# 1160        2208    ML Ops   Full Time           Senior
# 1161        2225    ML Ops   Full Time            Entry
# 1162        2232    ML Ops   Full Time           Senior
# 1163        2237    ML Ops   Full Time           Senior
# 1164        2239    ML Ops   Full Time           Senior
# 1165        2240    ML Ops   Full Time           Senior
# 1166        2243    ML Ops   Full Time           Senior
# 1167        2249    ML Ops   Full Time           Senior
# 1168        2250    ML Ops   Full Time           Senior
# 1169        2255    ML Ops   Full Time           Senior
# 1170        2259    ML Ops  Internship           Senior
#
#                           location salary_currency  salary
# 1159                      Santiago             USD   45000
# 1160                 San Francisco             USD   68000
# ...

# %%
df.sample(6)
# Out:
#       Unnamed: 0         job_title   job_type experience_level    location  \
# 220          270    Data scientist  Full Time           Senior    New York
# 1032        1857  Machine learning  Full Time           Senior       India
# 733         1049      Data analyst  Full Time            Entry      Kraków
# 794         1263          Big data  Full Time           Senior   São Paulo
# 908         1555  Machine learning  Full Time           Senior  Remote- US
# 1099        2033  Machine learning  Full Time           Senior    San Jose
#
#      salary_currency  salary
# 220              USD  145000
# 1032             USD   45000
# 733              USD   30000
# 794              USD   30000
# 908              USD  150000
# 1099             USD   45000

# %%
df[['location','salary','experience_level']]
# Out:
#            location  salary experience_level
# 0     New York City  149000           Senior
# 1            Boston  120000           Senior
# 2            London   68000           Senior
# 3            Boston  120000           Senior
# 4     New York City  149000           Senior
# ...             ...     ...              ...
# 1166        Toronto  228000           Senior
# 1167         Boston  115000           Senior
# 1168          Delhi   76000           Senior
# 1169  San Francisco   68000           Senior
# 1170  New York City  135000           Senior
#
# [1171 rows x 3 columns]

# %%
df["salary"].mean()
# Out:
# 64836.03757472246

# %%
df['location'].unique().tolist()
# Out:
# ['New York City',
#  'Boston',
#  'London',
#  'Research Triangle Park',
#  'Sydney',
#  'San Francisco',
#  'Sofia',
#  'BangPa-in',
#  'Berlin',
#  'NAMER',
#  'Remote',
#  'San Jose',
#  'Petaling Jaya',
#  'Englewood',
#  'Pune',
#  'Paris',
#  'Gothenburg',
#  'Mountain View',
#  'Porto',
#  'Ontario',
#  'Brooklyn',
#  'Remote- US',
#  'Cambridge',
#  'La Libertad',
#  'Lithuania | UK',
#  'Chicago',
#  'United Kingdom - Remote',
#  'Santiago',
#  'Nairobi',
#  'Luxembourg',
#  'San Francisco OR Remote US Canada',
#  'Lyon',
#  'Montreal',
#  'Princeton',
#  'California',
#  'Athens',
#  'Charenton-Le-Pont',
#  'Aberdeen',
#  'Brampton',
#  'Salt Lake City',
#  'Munich',
#  'Oslo',
#  'Basel',
#  'Düsseldorf',
#  'Madrid',
#  'Austin',
#  'Dallas',
#  'Warsaw',
#  'Houston',
#  'Hyderabad',
#  'Zurich',
#  'Palaiseau',
#  'Burnaby',
#  'Lisbon',
#  'Tel Aviv-Yafo',
#  'United States',
#  'Toronto',
#  'Indianapolis',
#  'New York',
#  'Dayton',
#  'Seoul',
#  'Glasgow',
# ...

# %%
df['location'].value_counts()
# Out:
# London                    75
# Remote                    50
# San Francisco             43
# Bengaluru                 34
# Paris                     33
#                           ..
# Bogota                     1
# Kampala                    1
# Kirkland                   1
# Riga                       1
# New York City / Remote     1
# Name: location, Length: 320, dtype: int64

# %%
x=df['salary']>80000
print(x)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1166     True
# 1167     True
# 1168    False
# 1169    False
# 1170     True
# Name: salary, Length: 1171, dtype: bool

# %%
x= (df['salary']>80000) & (df['experience_level']=='senior')
print(x)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1166    False
# 1167    False
# 1168    False
# 1169    False
# 1170    False
# Length: 1171, dtype: bool

# %%
x= (df['salary']>80000) & (df['salary']<120000) & (df['experience_level']=='senior')
print(x)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1166    False
# 1167    False
# 1168    False
# 1169    False
# 1170    False
# Length: 1171, dtype: bool

# %%
df.isnull().any(axis=0)
# Out:
# Unnamed: 0          False
# job_title           False
# job_type            False
# experience_level    False
# location            False
# salary_currency     False
# salary              False
# dtype: bool

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, job_title, job_type, experience_level, location, salary_currency, salary]
# Index: []

# %%
myVar.dropna(inplace=False)
# Out:
#    cars  passings
# 0   BMW         3
# 1  Audi         7
# 2  Merc         2

# %%
new_df=myVar.dropna()
print(new_df.to_string())
# Out:
#    cars  passings
# 0   BMW         3
# 1  Audi         7
# 2  Merc         2

# %%
data2=myVar.fillna(10)
